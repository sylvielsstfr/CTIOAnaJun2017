# %% [markdown]
# # Plot the time series correctly using matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd

# %%
import datetime
from dateutil import parser  # very usefull time format smart parser

# %%
import os

# %%
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
days=mdates.DayLocator()  # every day
hour=mdates.HourLocator()  # every day
yearsFmt = mdates.DateFormatter('%Y')

# %%
# %config InlineBackend.rc = {}
mpl.rc_file("../templates/matplotlibrc")
# Out:
# /Users/dagoret-campagnesylvie/anaconda/envs/pyastrophys/lib/python2.7/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
import matplotlib 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)

# %%
# !ls
# Out:
# PltObs.ipynb             am_vs_time.pdf           pressurevstime.pdf
# airmassvstime.pdf        arcsec.pdf               seeing_vs_time.pdf
# allamseeing.pdf          ctioobsinfo_jun2017.csv
# am.pdf                   observations_fullprod.py

# %%
pandasobsfile='ctioobsinfo_jun2017.csv'

# %%
df=pd.read_csv(pandasobsfile)

# %%
listOfObjects=['HD185975','HD111980','HD205905','HD160617','QSO_3C273','QSO_PKS1510-089']

# %%
df0=df[df["object"]==listOfObjects[0]]
df1=df[df["object"]==listOfObjects[1]]
df2=df[df["object"]==listOfObjects[2]]
df3=df[df["object"]==listOfObjects[3]]

# %%
df4=df[df["object"]==listOfObjects[4]]

# %%
df0
# Out:
#       Unnamed: 0  airmass                     date disperser filter    object  \
# 116          116    1.931  2017-05-29T04:16:11.205  HoloAmAg    dia  HD185975
# 117          117    1.929  2017-05-29T04:18:29.109   Thor300    dia  HD185975
# 118          118    1.929  2017-05-29T04:19:51.453   HoloPhP    dia  HD185975
# 119          119    1.928  2017-05-29T04:21:13.848  HoloPhAg    dia  HD185975
# 120          120    1.924  2017-05-29T04:27:42.796   Thor300    dia  HD185975
# 121          121    1.924  2017-05-29T04:29:05.003   HoloPhP    dia  HD185975
# 122          122    1.923  2017-05-29T04:30:27.353  HoloPhAg    dia  HD185975
# 123          123    1.922  2017-05-29T04:32:19.652  HoloAmAg    dia  HD185975
# 124          124    1.921  2017-05-29T04:34:11.953   Thor300    dia  HD185975
# 125          125    1.920  2017-05-29T04:35:34.307   HoloPhP    dia  HD185975
# 126          126    1.919  2017-05-29T04:36:56.649  HoloPhAg    dia  HD185975
# ...

# %%
all_dates=df["date"]

# %%
z=df["airmass"]
seeing=df["seeing"]
obj=df["object"]
thefilter=df["filter"]
disperser=df["disperser"]

# %%
NDATA=len(all_dates)
all_dt= [ parser.parse(all_dates[i]) for i in range(NDATA)]

# %%
all_dates0=df0["date"]

# %%
for thedate in all_dates0:
    print thedate
# Out:
# 2017-05-29T04:16:11.205
# 2017-05-29T04:18:29.109
# 2017-05-29T04:19:51.453
# 2017-05-29T04:21:13.848
# 2017-05-29T04:27:42.796
# 2017-05-29T04:29:05.003
# 2017-05-29T04:30:27.353
# 2017-05-29T04:32:19.652
# 2017-05-29T04:34:11.953
# 2017-05-29T04:35:34.307
# 2017-05-29T04:36:56.649
# 2017-05-29T04:38:48.901
# 2017-05-29T04:40:41.252
# 2017-05-29T04:42:03.656
# 2017-05-29T04:43:26.000
# 2017-05-29T04:45:18.404
# 2017-05-29T04:47:10.801
# 2017-05-29T04:48:33.204
# 2017-05-29T04:49:55.555
# 2017-05-29T04:51:47.853
# 2017-05-29T04:53:39.955
# 2017-05-29T04:55:02.304
# 2017-05-29T04:56:24.501
# 2017-05-29T04:58:16.845
# 2017-05-29T05:00:09.302
# 2017-05-29T05:01:31.648
# 2017-05-29T05:02:53.953
# 2017-05-29T05:04:46.402
# 2017-05-29T05:06:38.802
# 2017-05-29T05:08:01.157
# 2017-05-29T05:09:23.554
# 2017-05-29T05:11:16.002
# 2017-05-29T05:13:08.396
# 2017-05-29T05:14:30.800
# 2017-05-29T05:15:53.203
# 2017-05-29T05:17:45.597
# 2017-05-29T05:19:37.954
# 2017-05-29T05:21:00.196
# ...

# %%
all_dates0=df0["date"]
all_dt0= [ parser.parse(thedate) for thedate in all_dates0]

# %%
all_dates1=df1["date"]
NDATA1=len(all_dates1)
all_dt1= [ parser.parse(thedate) for thedate in all_dates1]

# %%
all_dates2=df2["date"]
NDATA2=len(all_dates2)
all_dt2= [ parser.parse(thedate) for thedate in all_dates2]

# %%
all_dates3=df3["date"]
NDATA3=len(all_dates3)
all_dt3= [ parser.parse(thedate) for  thedate in all_dates3]

# %%
fig=plt.figure(figsize=(18,8))

ax=fig.add_subplot(1,1,1)

plt.xticks(rotation=45)

ax.plot_date(all_dt0,df0["airmass"],marker='o',color='red',lw=0,label=listOfObjects[0],linewidth=3)

ax.plot_date(all_dt1,df1["airmass"],marker='o',color='blue',lw=0,label=listOfObjects[1],linewidth=3)

ax.plot_date(all_dt2,df2["airmass"],marker='o',color='green',lw=0,label=listOfObjects[2],linewidth=3)

ax.plot_date(all_dt3,df3["airmass"],marker='o',color='magenta',lw=0,label=listOfObjects[3],linewidth=3)

#date_range = all_dt[NDATA-1] - all_dt[0]
date_range = all_dt[NDATA-1] - parser.parse('2017-05-25T00:00:00.000')

if date_range > datetime.timedelta(days = 1):
    ax.xaxis.set_major_locator(mdates.DayLocator(bymonthday=range(1,32), interval=1))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    ax.get_xaxis().set_minor_locator(mdates.HourLocator(byhour=range(0,24,2)))
    ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
else:
    ax.xaxis.set_major_locator(mdates.HourLocator(byhour=range(0,24,2)))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
    ax.get_xaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    ax.get_xaxis().set_minor_locator(mdates.MinuteLocator(byminute=range(0,60,5)))
    
#ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())

#ax.grid(b=True, which='major', color='lightgrey', linewidth=2.0)
#ax.grid(b=True, which='minor', color='blue', linewidth=0.5)
ax.set_ylabel('airmass',fontsize=30)
ax.set_xlabel('time',fontsize=30)
#ax.set_xlim(parser.parse('2017-05-25T00:00:00.000'),parser.parse('2017-06-15T00:00:00.000'))
ax.set_ylim(0.5,2.5)

title='airmass vs time'
plt.title(title,fontsize=40)
plt.legend(loc=1,fontsize=20)

figfilename='airmassvstimecolor.pdf'
fig.savefig(figfilename)

# %%
fig=plt.figure(figsize=(18,8))

ax=fig.add_subplot(1,1,1)

plt.xticks(rotation=45)

ax.plot_date(all_dt0,df0["seeing"],marker='o',color='red',lw=0,label=listOfObjects[0],linewidth=3)

ax.plot_date(all_dt1,df1["seeing"],marker='o',color='blue',lw=0,label=listOfObjects[1],linewidth=3)

ax.plot_date(all_dt2,df2["seeing"],marker='o',color='green',lw=0,label=listOfObjects[2],linewidth=3)

ax.plot_date(all_dt3,df3["seeing"],marker='o',color='magenta',lw=0,label=listOfObjects[3],linewidth=3)

#date_range = all_dt[NDATA-1] - all_dt[0]
date_range = all_dt[NDATA-1] - parser.parse('2017-05-25T00:00:00.000')

if date_range > datetime.timedelta(days = 1):
    ax.xaxis.set_major_locator(mdates.DayLocator(bymonthday=range(1,32), interval=1))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    ax.get_xaxis().set_minor_locator(mdates.HourLocator(byhour=range(0,24,2)))
    ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
else:
    ax.xaxis.set_major_locator(mdates.HourLocator(byhour=range(0,24,2)))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
    ax.get_xaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    ax.get_xaxis().set_minor_locator(mdates.MinuteLocator(byminute=range(0,60,5)))
    
#ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())

#ax.grid(b=True, which='major', color='lightgrey', linewidth=2.0)
#ax.grid(b=True, which='minor', color='blue', linewidth=0.5)
ax.set_ylabel('seeing (arcsec)',fontsize=30)
ax.set_xlabel('time',fontsize=30)
#ax.set_xlim(parser.parse('2017-05-25T00:00:00.000'),parser.parse('2017-06-15T00:00:00.000'))
#ax.set_ylim(0.5,2.5)

title='seeing vs time'
plt.title(title,fontsize=40)
plt.legend(loc=1,fontsize=20)

figfilename='seeingvstimecolor.pdf'
fig.savefig(figfilename)

# %%
plt.plot

# %%
def PlotTimeSerie(all_dt,data,title,xtitle,ytitle,labeltitle,thecolor,figfilename):
    
    
        
    fig=plt.figure(figsize=(25,8))

    ax=fig.add_subplot(1,1,1)
    ax.plot_date(all_dt, data,marker='o',color=thecolor,lw=0,label=labeltitle,linewidth=3)


    date_range = all_dt[NDATA-1] - all_dt[0]

    if date_range > datetime.timedelta(days = 1):
        ax.xaxis.set_major_locator(mdates.DayLocator(bymonthday=range(1,32), interval=1))
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
        ax.get_xaxis().set_minor_locator(mdates.HourLocator(byhour=range(0,24,2)))
        #ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    else:
        ax.xaxis.set_major_locator(mdates.HourLocator(byhour=range(0,24,2)))
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
        #ax.get_xaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
        ax.get_xaxis().set_minor_locator(mdates.MinuteLocator(byminute=range(0,60,5)))
    
    ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())

    ax.grid(b=True, which='major', color='k', linewidth=2.0)
    ax.grid(b=True, which='minor', color='grey', linewidth=0.5)
    ax.set_ylabel(ytitle,fontsize=30)
    ax.set_xlabel(xtitle,fontsize=30)


  
    plt.title(title,fontsize='40')
    plt.legend(loc='best')


    fig.savefig(figfilename)

# %%
PlotTimeSerie(all_dt,z,"airmass vs time","time","z","airmass","red","am_vs_time.pdf")

# %%
PlotTimeSerie(all_dt,seeing,"Seeing vs time","time","seeing (arcsec)","seeing","blue","seeing_vs_time.pdf")

# %%
def PlotAllTimeSerie(all_dt,data1,data2,title,figfilename):
    
    
        
    fig=plt.figure(figsize=(25,12))
    plt.title(title,fontsize=40)
    ax1=fig.add_subplot(2,1,1)
    ax1.plot_date(all_dt, data1,marker='o',color="red",lw=0,label="Pressure",linewidth=3)
    
    ax2=fig.add_subplot(2,1,2)
    ax2.plot_date(all_dt, data2,marker='o',color="blue",lw=0,label="Temperature",linewidth=3)

   

    date_range = all_dt[NDATA-1] - all_dt[0]

    if date_range > datetime.timedelta(days = 1):
        ax1.xaxis.set_major_locator(mdates.DayLocator(bymonthday=range(1,32), interval=1))
        ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
        ax1.get_xaxis().set_minor_locator(mdates.HourLocator(byhour=range(0,24,2)))
        ax2.xaxis.set_major_locator(mdates.DayLocator(bymonthday=range(1,32), interval=1))
        ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
        ax2.get_xaxis().set_minor_locator(mdates.HourLocator(byhour=range(0,24,2)))

       
    else:
        ax1.xaxis.set_major_locator(mdates.HourLocator(byhour=range(0,24,2)))
        ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
        ax1.get_xaxis().set_minor_locator(mdates.MinuteLocator(byminute=range(0,60,5)))
        
        ax2.xaxis.set_major_locator(mdates.HourLocator(byhour=range(0,24,2)))
        ax2.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
        ax2.get_xaxis().set_minor_locator(mdates.MinuteLocator(byminute=range(0,60,5)))
        

    
    ax1.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    ax1.grid(b=True, which='major', color='k', linewidth=2.0)
    ax1.grid(b=True, which='minor', color='grey', linewidth=0.5)
    ax1.set_ylabel("pressure (hPa)",fontsize=30)
    ax1.set_xlabel("time",fontsize=30)

    ax2.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    ax2.grid(b=True, which='major', color='k', linewidth=2.0)
    ax2.grid(b=True, which='minor', color='grey', linewidth=0.5)
    ax2.set_ylabel("Temperature (deg C)",fontsize=30)
    ax2.set_xlabel("time",fontsize=30)
    
    
  
   
    plt.legend(loc='best')


    fig.savefig(figfilename)

# %%
PlotAllTimeSerie(all_dt,z,seeing,"airmass and seeing","allamseeing.pdf")

# %% [markdown]
# ## draw histogram

# %%
seeing=np.array(seeing)

# %%
seeing_cut=seeing[np.where(seeing>0)]

# %%
mean=seeing_cut.mean()
std=seeing_cut.std()
thelabel="mean={:2.2f} rms={:2.2f}".format(mean,std)

print thelabel

# %%
plt.hist(seeing_cut,bins=50,color="blue",alpha=0.5,label=thelabel)
plt.legend()
plt.title("Seeing at CTIO (jun 2017)")
plt.xlabel("seeing (arcsec)")
plt.savefig("arcsec.pdf")
