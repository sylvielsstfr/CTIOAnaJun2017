# %% [markdown]
# # Find the central PNG of CTIO Data in May 2017
# ==================================================================================================
#
# - author : Jérémy Neveu
# - date   : June 5th 2017
#
#
# The goal of this notebook is to cut a part of the image around the main central star.
# The rest of the image is useless.
# This region around the central star is necessary to perform the rotation of the images without
# any biases due to other stars.

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "theNotebook = " + "'"+thename+"'";
# kernel.execute(command);

# %%
print theNotebook
# Out:
# FindCentralStar

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from astropy.modeling import models
from astropy import units as u
from astropy import nddata
from astropy.io import fits
import re
import os

# %%
import ccdproc
print 'ccdproc version',ccdproc.__version__

from astropy.modeling import models
# Out:
# ccdproc version 1.2.0

# %%
from scipy import stats  
from scipy import ndimage
from datetime import datetime, timedelta
from mpl_toolkits.mplot3d import Axes3D
import scipy.signal

# %%
import bottleneck as bn  # numpy's masked median is slow...really slow (in version 1.8.1 and lower)
print 'bottleneck version',bn.__version__
# Out:
# bottleneck version 1.2.0

# %%
import photutils
from astropy.stats import sigma_clipped_stats
from photutils import daofind
from photutils import CircularAperture
from astropy.visualization import SqrtStretch
from astropy.visualization.mpl_normalize import ImageNormalize
#from photutils.background import Background2D
from photutils import Background2D, SigmaClip, MedianBackground

# %%
# %load_ext Cython

# %%
from IPython.display import Image, display

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (4, 4),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
############################################################################
def ensure_dir(f):
    d = os.path.dirname(f)
    if not os.path.exists(f):
        os.makedirs(f)
#########################################################################

# %% [markdown]
# ### Output directory for images generated in the notebook view (not true fits images)¶

# %%
dir_top_images="images_notebooks/"+theNotebook ### Top directory to save images

# %%
ensure_dir(dir_top_images) # create that directory

# %% [markdown]
# ### Input directory

# %%
# !ls ../OverScanRemove/trim_images
# Out:
# trim_20170605_004.fits trim_20170605_010.fits trim_20170605_017.fits
# trim_20170605_005.fits trim_20170605_011.fits trim_20170605_026.fits
# trim_20170605_006.fits trim_20170605_012.fits trim_20170605_027.fits
# trim_20170605_007.fits trim_20170605_013.fits trim_20170605_028.fits
# trim_20170605_008.fits trim_20170605_014.fits trim_20170605_029.fits
# trim_20170605_009.fits trim_20170605_016.fits

# %%
inputdir="../OverScanRemove/trim_images"
MIN_IMGNUMBER=26
MAX_IMGNUMBER=29
object_name='PNG321.0+3.9'
SelectTagRe='^trim_20170605_([0-9]+).fits$' # regular expression to select the file
SearchTagRe='^trim_20170605_[0-9]+.fits$'
NBIMGPERLROW=2

# %% [markdown]
# ### Output directory fot fits images

# %%
outputdir="./cut_fitsimages"

# %%
ensure_dir(outputdir)

# %% [markdown]
# ## Location of corrected images
# ----------------------------------

# %%
input_filelist=os.listdir(inputdir)

# %%
if '.DS_Store' in input_filelist:
    input_filelist.remove('.DS_Store')
input_filelist=np.array(input_filelist)

# %%
print input_filelist[:5]
# Out:
# ['trim_20170605_004.fits' 'trim_20170605_005.fits' 'trim_20170605_006.fits'
#  'trim_20170605_007.fits' 'trim_20170605_008.fits']

# %%
indexes_files= [] # global list
filelist_fitsimages= []  # global list
dirlist_all = [inputdir]

# %%
def MakeFileList():
    """
    MakeFileList : Make The List of files to open
    =============
    
    - we select the files which are of interest.
    - In particular select the number range
    
    """
    count=0
    
    for dir in dirlist_all: # loop on directories, one per image   (if necessary)    
            dir_leaf= dir # build the name of leaf directory
            listfiles=os.listdir(dir_leaf) 
            for filename in listfiles:
                if re.search(SearchTagRe,filename):  #example of filename filter
                    str_index=re.findall(SelectTagRe,filename)
                    count=count+1
                    index=int(str_index[0])
                    if index >= MIN_IMGNUMBER and index <= MAX_IMGNUMBER: 
                        indexes_files.append(index)         
                        shortfilename=dir_leaf+'/'+filename
                        filelist_fitsimages.append(shortfilename)
                    
    return

# %%
MakeFileList()   # Make the list

# %%
indexes_files=np.array(indexes_files)
filelist_fitsimages=np.array(filelist_fitsimages)

# %%
sorted_indexes=np.argsort(indexes_files) # sort the file indexes

# %%
sorted_numbers=indexes_files[sorted_indexes]

# %%
#sorted_files= [filelist_fitsimages[index] for index in sorted_indexes] # sort files
sorted_files=filelist_fitsimages[sorted_indexes]

# %% [markdown]
# ## Build full filename
# ----------------------------

# %%
sorted_filenames=[]
for file in sorted_files:
    #fullfilename=os.path.join(inputdir,file)
    fullfilename=file
    sorted_filenames.append(fullfilename)

# %%
#sorted_filenames=np.array(sorted_filenames)
sorted_filenames=np.copy(sorted_files)

# %% [markdown]
# ## Acces to data of  images
# ----------------------------------

# %%
all_dates = []
all_airmass = []
all_images = []
all_titles = []
all_header = []
all_img = []
all_filt = []

# %%
# %%cython
#
# import numpy as np
# from astropy.io import fits
#
# def BuildImages(sorted_filenames,sorted_numbers,object_name):
#     """
#     BuildRawImages
#     ===============
#     """
#
#
#     all_dates = []
#     all_airmass = []
#     all_images = []
#     all_titles = []
#     all_header = []
#     all_filt = []
#
#     NBFILES=sorted_filenames.shape[0]
#
#     for idx in range(NBFILES):
#
#         file=sorted_filenames[idx]
#
#         hdu_list=fits.open(file)
#         header=hdu_list[0].header
#         #print header
#         date_obs = header['DATE-OBS']
#         airmass = header['AIRMASS']
#         filters = header['FILTERS']
#
#         num=sorted_numbers[idx]
#         title=object_name+" z= {:3.2f} Nb={}".format(float(airmass),num)
#         image_corr=hdu_list[0].data
#         image=image_corr
#
#         all_dates.append(date_obs)
#         all_airmass.append(float(airmass))
#         all_images.append(image)
#         all_titles.append(title)
#         all_header.append(header)
#         all_filt.append(filters)
#         hdu_list.close()
#
#     return all_dates,all_airmass,all_images,all_titles,all_header,all_filt

# %%
all_dates,all_airmass,all_images,all_titles,all_header,all_filt=BuildImages(sorted_files,sorted_numbers,object_name)

# %%
#all_filt

# %% [markdown]
# ## Show images
# -----------------------

# %%
len(all_images)
# Out:
# 4

# %%
def ShowRawImages():
    """
    ShowRawImages: Show the raw images without background subtraction
    ==============
    """
    #global all_images
    #global all_titles
    #global object_name

    NBIMAGES=len(all_images)
    MAXIMGROW=int(NBIMAGES/NBIMGPERLROW)

    f, axarr = plt.subplots(MAXIMGROW,NBIMGPERLROW,figsize=(25,10*MAXIMGROW))
    for index in np.arange(0,NBIMAGES):
        ix=index%NBIMGPERLROW
        iy=index/NBIMGPERLROW
        #im=axarr[iy,ix].imshow(all_images[index],origin='lower',cmap='rainbow',norm=LogNorm(vmin=0.1, vmax=10))
        im=axarr[iy,ix].imshow(all_images[index],origin='lower',cmap='rainbow')
        axarr[iy,ix].set_title(all_titles[index])
        axarr[iy,ix].grid(color='white', ls='solid')
        axarr[iy,ix].text(1000.,1700,all_filt[index],verticalalignment='bottom', horizontalalignment='center',color='yellow', fontweight='bold',fontsize=16)
    title='Raw images of {}'.format(object_name)
    plt.suptitle(title,size=16)    
    figfilename=os.path.join(dir_top_images,'input_images.pdf')
    plt.savefig(figfilename)

# %%
ShowRawImages()

# %% [markdown]
# ### Find the star locations
# ----------------------------

# %%
# %%cython
# import photutils
# from astropy.stats import sigma_clipped_stats
# from photutils import daofind
#
# def ComputeStatImages(all_images):
#     """
#     ComputeStatImages:
#     ==============
#     """
#
#     img_mean=[]
#     img_median=[]
#     img_std=[]
#     img_sources=[]
#     img_=[]
#     index=0
#     for image in all_images:
#         mean, median, std = sigma_clipped_stats(image, sigma=10.0, iters=5)
#         print '----------------------------------------------------------------'
#         print index,' mean, median, std = ',mean, median, std
#         img_mean.append(mean)
#         img_median.append(median)
#         img_std.append(std)
#         sources = daofind(image - median, fwhm=3, threshold=10*std) # (JN) valeurs optimisées pour cette étude
#         print sources
#         img_sources.append(sources)
#         index+=1
#     return img_mean,img_median,img_std,img_sources

# %%
img_mean,img_median,img_std,img_sources=ComputeStatImages(all_images)
# Out:
# ----------------------------------------------------------------
# 0  mean, median, std =  3977.93542084 4906.0 2063.030572
# WARNING: AstropyDeprecationWarning: The daofind function is deprecated and may be removed in a future version.
#         Use DAOStarFinder instead. [astropy.utils.decorators]
#  id   xcentroid     ycentroid   ...   peak       flux            mag
# --- ------------- ------------- ... ------- ------------- -----------------
#   1 1486.13085183 75.5131654723 ... 56006.0 1.42154324662   -0.381900191165
#   2 1485.54501765 75.6727773934 ... 56739.0 1.46183781823   -0.412247982586
#   3 428.431815446 91.2698820575 ... 55870.0 1.54042644397   -0.469102413499
#   4 428.677307913  91.501439062 ... 55868.0 1.45257881421   -0.405349264271
#   5 428.637600839 91.1411580789 ... 55862.0 1.23903260136   -0.232706834146
#   6 657.833935488 99.4395366498 ... 29316.0  1.0751155315  -0.0786378396966
#   7 1357.23099081 118.049050284 ... 47211.0 1.52943167172   -0.461325198464
#   8 657.008147476 128.369617006 ... 55869.0 1.48639197429   -0.430333379254
#   9 656.691771432 128.667030416 ... 55687.0 1.49551737039   -0.436978654288
#  10 657.316860029 127.790114613 ... 55645.0 1.25813524721   -0.249318323679
# ...           ...           ... ...     ...           ...               ...
# 159 1230.89069398 1850.97077906 ... 32384.0 1.00746062975 -0.00807020870585
# 160 601.044218237 1857.39548379 ... 35797.0 1.17624268778   -0.176242341534
# 161  681.98112984 1857.37876253 ... 56799.0 1.86761354557   -0.678217537888
# 162 1768.41042726 1858.10731158 ... 55405.0 1.42426953071   -0.383980458895
# 163 1371.28811611 1908.97877049 ... 52391.0 1.73143488275    -0.59601540721
# 164 368.762880563 1925.63945506 ... 56963.0 1.46684017961   -0.415956994061
# 165 371.572995415 1925.99592622 ... 55954.0  1.4263979667   -0.385601777725
# 166 368.704004299 1927.31233704 ... 56930.0 1.58232434181    -0.49823877284
# 167 1212.52927531 1953.95956518 ... 55472.0 1.76102096029   -0.614411312809
# 168   1211.669768 1955.07164222 ... 55460.0 1.19563930603   -0.194000459531
# 169 1212.54652116 1958.27855665 ... 55474.0 1.58881979157   -0.502686602734
# Length = 169 rows
# ----------------------------------------------------------------
# 1  mean, median, std =  285.704916585 20.0 723.238860738
#  id   xcentroid     ycentroid   ...   peak       flux           mag
# --- ------------- ------------- ... ------- ------------- ----------------
#   1 701.643306657 417.248797866 ... 22463.0 1.87427888474  -0.682085531338
#   2 775.320372188 449.134566119 ... 14373.0 1.09601712059 -0.0995433454958
#   3 764.847876631  451.59823974 ... 29781.0 2.45633989851  -0.975721156409
#   4 514.214367801 494.834118597 ... 20703.0 1.74031009838  -0.601566600616
#   5 809.906683428 496.715995273 ... 23323.0 1.88323123395  -0.687259121155
#   6 597.044179645 510.764795041 ... 14112.0 1.06352285649 -0.0668670697359
#   7  785.13830451 516.585692701 ... 21112.0 1.62946372262  -0.530111740105
#   8 815.680243807 530.563526018 ... 21875.0 1.75759719715  -0.612298378351
#   9 611.095173405 531.620456055 ... 18167.0 1.36430912598  -0.337281960434
#  10 684.886455542  567.84141989 ... 14753.0 1.03989209133 -0.0424706882169
# ...           ...           ... ...     ...           ...              ...
#  60 589.615956912 804.525085954 ... 60557.0 4.39802563927   -1.60814439212
#  61 725.302810901 812.393204781 ... 18121.0 1.33606846996  -0.314571787873
#  62 740.252754638 835.119811694 ... 20346.0 1.45035527283  -0.403685995467
#  63 549.804486826 836.829772539 ... 42375.0 3.76434542395   -1.43922367081
#  64 968.497057129 841.713510331 ... 14749.0 1.24178555077  -0.235116505382
#  65 599.967613306 857.391856982 ... 13059.0  1.0282062792 -0.0302006293754
#  66 839.772796116 865.331044046 ... 25770.0 2.17413653679  -0.843217036257
#  67  806.05396111 878.578660557 ... 60760.0 4.22188226431   -1.56376529491
#  68 806.747557551 879.003358616 ... 60757.0 5.47766696682   -1.84648906082
#  69  704.86661704 881.736357902 ... 13830.0 1.09879119612  -0.102287927625
#  70 714.758450821 898.365394919 ... 60662.0 5.41941763358   -1.83488155024
# Length = 70 rows
# ----------------------------------------------------------------
# 2  mean, median, std =  285.102078735 23.0 804.310288561
#  id   xcentroid     ycentroid   ...   peak       flux           mag
# --- ------------- ------------- ... ------- ------------- ----------------
#   1  762.29527994 308.956649092 ... 17656.0 1.44617292719  -0.400550567864
#   2 788.664057553 358.414956217 ... 35935.0 2.87596056247   -1.14695731587
#   3 903.785590958 363.623507919 ... 15509.0 1.18027126831  -0.179954587735
#   4 862.246481445 390.340641413 ... 23860.0 1.78330703805  -0.628065308935
#   5  851.72743741 392.804093022 ... 49530.0 4.03949021001   -1.51581639981
#   6 671.564197428 403.693899351 ... 15500.0 1.12476946633   -0.12765879554
#   7 891.960598645 417.514271687 ... 17529.0 1.17903742718  -0.178818978725
#   8 601.012749111 435.933216899 ... 34716.0 2.82357419124   -1.12699800898
#   9 1007.60785669 436.813793208 ... 16287.0 1.21580016297  -0.212155493159
#  10 896.671183476  437.95122975 ... 33208.0 2.62115715959   -1.04623265299
# ...           ...           ... ...     ...           ...              ...
#  82 676.496134435 747.461478023 ... 60756.0 3.89552848471   -1.47641596081
#  83 812.145220701 753.740488705 ... 24090.0 1.84915818117  -0.667435158197
#  84 827.190638399 776.370573083 ... 24893.0 1.76824262708  -0.618854639777
#  85 636.666622275 777.939563421 ... 60307.0 5.21771230445   -1.79370032296
#  86 1054.89367685 782.916305764 ... 12883.0 1.08605155633 -0.0896261057173
#  87 686.857628128 798.469945801 ... 17648.0  1.4246395627  -0.384262501683
#  88 926.427285939  806.50482751 ... 29468.0 2.37750330853  -0.940302824932
#  89 892.976733977 819.893026278 ... 60755.0 4.01959648122   -1.51045614342
#  90 895.521867511   819.9918026 ... 60670.0  4.0497933938   -1.51858216901
#  91 791.832178803 822.797220913 ... 17077.0 1.38354563693  -0.352483722821
#  92 801.833051959 839.455469213 ... 60748.0 4.98725388246   -1.74465369273
# Length = 92 rows
# ----------------------------------------------------------------
# 3  mean, median, std =  24.7383251201 7.0 43.416293575
#  id   xcentroid     ycentroid   ...  peak       flux           mag
# --- ------------- ------------- ... ------ ------------- ----------------
#   1 47.9835653778 6.95718226453 ...  821.0 1.42402858618  -0.383796768718
#   2 1087.74428458 187.672581108 ... 1228.0 2.08509404785  -0.797814121348
#   3 1803.24771859 259.126363784 ...  947.0 1.64119685131  -0.537901687718
#   4 691.132923548 280.285375836 ...  751.0 1.33075911805  -0.310248626349
#   5 739.742840471 296.541212307 ...  823.0 1.43239725685  -0.390158701585
#   6 759.227904931 308.021021383 ...  825.0 1.22365229484  -0.219145072534
#   7 1978.68454964 320.255348845 ...  727.0 1.46091601081   -0.41156312182
#   8 1980.51363114 321.549979915 ...  672.0  1.3169757819   -0.29894447179
#   9 785.727334095 357.836237709 ... 1661.0 2.39906458058   -0.95010484732
#  10 1277.74103681 359.867070563 ...  837.0 1.29384437384  -0.279705104189
# ...           ...           ... ...    ...           ...              ...
#  91 1482.55250489 1525.01680708 ...  926.0 1.61888018116  -0.523036765822
#  92 1060.90786429 1621.46789326 ... 1042.0 2.06136905602  -0.785389381006
#  93 906.354971889 1637.73769105 ...  660.0 1.29952952277  -0.284465375673
#  94 1713.65731137 1674.32310546 ...  617.0 1.02159496727 -0.0231968619421
#  95 331.775425288 1725.65994412 ... 1272.0 2.35181016047  -0.928505655769
#  96 1953.74660963 1752.04241376 ...  746.0 1.26917533738  -0.258804060749
#  97 1353.11679706 1783.34850154 ... 1060.0 1.94972470516  -0.724933236778
#  98 136.570572526 1804.68624299 ... 1806.0 3.31250841629   -1.30039247596
#  99 1975.99274485 1806.55876246 ... 2364.0 4.33148636253   -1.59159237846
# 100  1262.0238636 1933.50047268 ... 2097.0 3.86713001733   -1.46847193449
# 101 639.641537948 2028.28215415 ...  856.0 1.57079076123   -0.49029584564
# Length = 101 rows

# %% [markdown]
# ### Central star position

# %%
x_guess = [740,740,800,800]
y_guess = [630,630,580,580]
x_star = []
y_star = []

for ss,s in enumerate(img_sources) :
    dist = 1e20
    k_star = -1
    for k in range(len(s)):
        x = s["xcentroid"][k]
        y = s["ycentroid"][k]
        test = (x-x_guess[ss])**2 + (y-y_guess[ss])**2
        if test < dist :
            dist = test
            k_star = k
    x_star.append(s["xcentroid"][k_star])
    y_star.append(s["ycentroid"][k_star])

# %%
print x_star
print y_star
# Default position
x0 = int(np.median(x_star))
y0 = int(np.median(y_star))
print x0,y0
# Out:
# [732.94213747688752, 732.64612980858476, 814.21968894452414, 813.95018934028531]
# [647.70809211031928, 635.06933945983155, 586.75600981654702, 586.94264479996389]
# 773 611

# %%
img_size=all_images[0].shape
plt.figure(figsize=(5,5))
plt.plot(x_star,y_star,'o')
plt.plot(x0,y0,'ro')
plt.xlim(0,img_size[1])
plt.ylim(0,img_size[0])
plt.grid(True)

# %% [markdown]
# ### Cut the image

# %%
DeltaY=50
DeltaX=600

# %%
#%%cython

import numpy as np
import matplotlib.pyplot as plt
from photutils import CircularAperture
import os

def ShowCenterImages(all_images,all_titles,object_name,dir_top_images):
    """
    ShowCenterImages: Show the raw images without background subtraction
    ==============
    """
    NBIMAGES=len(all_images)
    NBIMGPERLROW = 2
    MAXIMGROW=int(NBIMAGES/NBIMGPERLROW)
    
    #global dir_top_images
    
    croped_images = []
    f, axarr = plt.subplots(MAXIMGROW,NBIMGPERLROW,figsize=(25,5*MAXIMGROW))
    for index in np.arange(0,NBIMAGES):
        ix=index%NBIMGPERLROW
        iy=index/NBIMGPERLROW
       
        #image_cut=all_images[index][y0-200:y0+200,x0-200,y0+200]
        theimage=all_images[index]
        #image_cut=theimage[y0-DeltaY:y0+DeltaY,x0-DeltaX:x0+DeltaX]
        image_cut=np.copy(theimage[int(y_star[index])-DeltaY:int(y_star[index])+DeltaY,:])
        croped_images.append(image_cut)
        #aperture=CircularAperture([positions_central[index]], r=100.)
        im=axarr[iy,ix].imshow(image_cut,cmap='rainbow',aspect='auto',origin='lower',interpolation='None')
        axarr[iy,ix].set_title(all_titles[index])
        axarr[iy,ix].grid(color='white', ls='solid')
        #aperture.plot(color='red', lw=5.)
    title='Cut Images of {}'.format(object_name)
    plt.suptitle(title,size=16) 
    
    figfilename=os.path.join(dir_top_images,'cut_images.pdf')
    plt.savefig(figfilename)   
    
    
    return croped_images

# %%
images_cut=ShowCenterImages(all_images,all_titles,object_name,dir_top_images)

# %% [markdown]
# #### Example of cut image
# -------------------------

# %%
index=0
data=np.copy(images_cut[index])
w=20
ws=80
#data[:,DeltaX-ws:DeltaX+ws]=0

# %%
yprofile=np.sum(data,axis=1)
xprofile=np.sum(data,axis=0)

# %%
y_center=np.where(yprofile==yprofile.max())[0][0]
print y_center
# Out:
# 46

# %%
plt.figure(figsize=(18,18))
plt.imshow(data,origin='lower',cmap='rainbow',interpolation='None')
plt.plot([0,data.shape[1]],[y_center-w,y_center-w],'r-',lw=1)
plt.plot([0,data.shape[1]],[y_center+w,y_center+w],'r-',lw=1)
plt.grid(color='white', ls='solid')
plt.show()
figfilename=os.path.join(dir_top_images,'cutimages_sample.pdf')
plt.savefig(figfilename)

# %% [markdown]
# ### prepare outputfilename

# %%
newfullfilenames=[]
for idx,file in np.ndenumerate(sorted_files):
    
    short_infilename=file.split("/")[3]
    print short_infilename
    short_partfilename=re.findall('^trim_(.*)',short_infilename)
    short_outfilename='cutimg_'+short_partfilename[0]
    newfullfilename=os.path.join(outputdir,short_outfilename)
    newfullfilenames.append(newfullfilename)
# Out:
# trim_20170605_026.fits
# trim_20170605_027.fits
# trim_20170605_028.fits
# trim_20170605_029.fits

# %% [markdown]
# ### Save outputfilename

# %%
for idx,file in np.ndenumerate(newfullfilenames):
    prihdu = fits.PrimaryHDU(header=all_header[idx[0]],data=images_cut[idx[0]])
    thdulist = fits.HDUList(prihdu)
    thdulist.writeto(file,overwrite=True)

# %%
# !ls -l cut_fitsimages/*
# Out:
# -rw-r--r--  1 jneveu  staff  1650240 19 jul 17:16 cut_fitsimages/cutimg_20170605_026.fits
# -rw-r--r--  1 jneveu  staff  1650240 19 jul 17:16 cut_fitsimages/cutimg_20170605_027.fits
# -rw-r--r--  1 jneveu  staff  1650240 19 jul 17:16 cut_fitsimages/cutimg_20170605_028.fits
# -rw-r--r--  1 jneveu  staff  1650240 19 jul 17:16 cut_fitsimages/cutimg_20170605_029.fits
