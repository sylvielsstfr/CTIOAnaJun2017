# %% [markdown]
# # Generic Simulation of observed spectrum
#
# - author : Sylvie Dagoret-Campagne
# - date july 8 th 2017
#
#
#
#
# ** Notice it can handle several type of input objects **

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

from astropy.modeling import models
from astropy import units as u
from astropy import nddata
from astropy.io import fits
from astropy.table import Table, Column
import re
import os

# %%
import pandas as pd

# %%
from matplotlib.backends.backend_pdf import PdfPages

# %%
import matplotlib 
matplotlib.rc('xtick', labelsize=25) 
matplotlib.rc('ytick', labelsize=25)

# %% [markdown]
# ### Import libradtan tools for simulation

# %%
import sys
sys.path.append('../spectrumsim/libradtransim')

# %%
from libsimulateTranspCTIOScattAbs import *

# %%
sys.path.append('../spectrumsim')
import libCTIOTransm as ctiosim

# %%
sys.path.append('../humidity')
import humidity as hum
import libhumidity_ctio as humctio

# %% [markdown]
# ### import pysynphot tools for CALSPEC SED

# %%
os.environ['PYSYN_CDBS']
# Out:
# '/Users/dagoret-campagnesylvie/MacOsX/External/PySyn_CDBS/grp/hst/cdbs'

# %%
import pysynphot as S
from astropy.io import ascii

# %% [markdown]
# ### CTIO Properties

# %%
path_ctiodata='../spectrumsim/CTIOThroughput'
qe_filename='qecurve.txt'

# %% [markdown]
# ### esthetic

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (8, 6),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
############################################################################
def ensure_dir(f):
    d = os.path.dirname(f)
    if not os.path.exists(f):
        os.makedirs(f)
#########################################################################

# %%
def truncate(f, n):
    '''Truncates/pads a float f to n decimal places without rounding'''
    s = '{}'.format(f)
    if 'e' in s or 'E' in s:
        return '{0:.{1}f}'.format(f, n)
    i, p, d = s.partition('.')
    return '.'.join([i, (d+'0'*n)[:n]])

# %%
calspec_sed={'HD111980':'hd111980_stis_003.fits','HD205905':'hd205905_stis_003.fits','HD185975':'hd185975_stis_003.fits'}

# %%
object_name='HD111980'

# %% [markdown]
# ## Definition of thermodynamic parameters

# %%
Pressure = 775.28625 # hPa  
Temperature = 0. # deg Celcius
Humidity=50.0

# %% [markdown]
# ## Compute pwv required for libradtran

# %%
pwv=humctio.HRtoPWV(Humidity/100.,Pressure,Temperature+273.0)

# %%
print pwv
# Out:
# 4.66402205415

# %% [markdown]
# ## Get quantum efficiency

# %%
wl_qe,tr_qe=ctiosim. Get_QE()

# %%
plt.plot(wl_qe,tr_qe)
plt.grid()
plt.title('Quantum efficiency')
plt.xlabel('wavelength (nm)')
plt.ylabel('transmission')

# %%
bp_ctio_qe = S.ArrayBandpass(wl_qe*10.,tr_qe, name='CTIO QE')

# %% [markdown]
# ## Get mirror

# %%
wl_m,tr_m=ctiosim. Get_Mirror()

# %%
plt.plot(wl_m,tr_m,'b-')
plt.grid()
plt.title('mirror transmission')
plt.xlabel('wavelength (A)')
plt.ylabel('transmission')

# %%
bp_ctio_m = S.ArrayBandpass(wl_m*10.,tr_m*tr_m, name='CTIO Mirror2')  # two mirrors

# %%
bp_ctio=bp_ctio_m*bp_ctio_qe

# %% [markdown]
# ### Get Filter

# %%
wl_f_red,tr_f_red=ctiosim.Get_RG175()
wl_f_blue,tr_f_blue=ctiosim.Get_FGB37()

# %%
bp_ctio_f_red = S.ArrayBandpass(wl_f_red*10.,tr_f_red, name='RG175')  # two mirrors
bp_ctio_f_blue = S.ArrayBandpass(wl_f_blue*10.,tr_f_blue, name='FGB37')  # two mirrors

# %%
plt.plot(bp_ctio_f_red.wave,bp_ctio_f_red.throughput,color='red',label='RG175')
plt.plot(bp_ctio_f_blue.wave,bp_ctio_f_blue.throughput,color='blue',label='FGB37')
plt.grid()
plt.title('filter transmission')
plt.xlabel('wavelength (A)')
plt.ylabel('transmission')
plt.legend()

# %% [markdown]
# ### Combine

# %% [markdown]
# #### With filter

# %%
bp_ctio_red=bp_ctio_qe*bp_ctio_m*bp_ctio_f_red
bp_ctio_blue=bp_ctio_qe*bp_ctio_m*bp_ctio_f_blue

# %% [markdown]
# #### witout filter

# %%
bp_ctio_nof=bp_ctio_qe*bp_ctio_m

# %% [markdown]
# ### Please select the bp_ctio below

# %%
plt.plot(wl_qe*10,tr_qe,'k-',label='QE')
plt.plot(bp_ctio_nof.wave,bp_ctio_nof.throughput,'g-',label='QE+mirror')
plt.plot(bp_ctio_red.wave,bp_ctio_red.throughput,'r-',label='QE+mirror+RG')
plt.plot(bp_ctio_blue.wave,bp_ctio_blue.throughput,'b-',label='QE+mirror+FB')
plt.title('all transmission at CTIO')
plt.xlabel('wavelength (A)')
plt.ylabel('transmission')
plt.grid()
plt.legend()
plt.savefig('all_transmission.pdf')

# %% [markdown]
# ## Get SED from CALSPEC
#
# - using Pysynphot

# %%
CTIO_COLL_SURF=0.9*(u.m)**2/(u.cm)**2  # LSST collectif surface
WLMIN=3000.
WLMAX=11000.

# %%
S.refs.setref(area=CTIO_COLL_SURF.decompose(), waveset=None)
S.refs.set_default_waveset(minwave=WLMIN, maxwave=WLMAX, delta=10, log=False)

# %% [markdown]
# # Simulate atmosphere

# %%
all_wl_atm= []
all_tr_atm= []
all_bp_atm = []
all_pwv=np.arange(0,10.5,0.5)
OZ=300.
AM=1

# %%
for index,pwv in np.ndenumerate(all_pwv):
    idx=index[0]
    #calculate the atmosphere
    path,file=ProcessSimulation(AM,pwv,OZ,Pressure)   
    fullfilename=os.path.join(path,file)
    atm_data=np.loadtxt(fullfilename)
    wl_atm=atm_data[:,0]
    tr_atm=atm_data[:,1]
    all_wl_atm.append(wl_atm)
    all_tr_atm.append(tr_atm)
    atm_filter_name='CTIO atm {}'.format(idx)
    bp_atm = S.ArrayBandpass(wl_atm*10.,tr_atm, name=atm_filter_name)  # Pysynphot pass band
    all_bp_atm.append(bp_atm)
# Out:
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  0.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv0_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv0_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv0_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv0_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  0.5
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv5_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv5_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv5_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv5_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  1.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv10_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv10_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv10_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv10_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  1.5
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv15_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv15_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv15_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv15_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  2.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv20_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv20_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv20_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv20_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  2.5
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv25_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv25_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv25_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv25_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  3.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv30_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv30_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv30_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv30_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  3.5
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv35_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv35_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv35_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv35_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  4.5
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv45_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv45_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv45_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv45_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  5.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv50_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv50_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv50_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv50_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  5.5
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv55_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv55_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv55_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv55_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  6.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv60_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv60_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv60_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv60_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  6.5
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv65_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv65_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv65_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv65_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  7.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv70_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv70_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv70_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv70_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  7.5
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv75_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv75_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv75_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv75_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  8.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv80_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv80_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv80_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv80_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  8.5
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv85_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv85_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv85_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv85_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  9.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv90_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv90_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv90_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv90_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  9.5
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv95_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv95_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv95_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv95_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1
#  2) pwv =  10.0
#  3) oz =  300.0
#  4) pressure  =  775.28625
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv100_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv100_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv100_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv100_oz30.OUT')

# %% [markdown]
# ## Observed spectra
#
# - calculate the observed spectra and save it in list

# %%
all_obs_spectra = []
all_obs_wl= []
all_obs_fluxes = []

for index,pwv in np.ndenumerate(all_pwv):
    idx=index[0]
     # retrieve the SED
    theobjectname=object_name
    sed_filename = os.path.join(os.environ['PYSYN_CDBS'], 'calspec',calspec_sed[theobjectname])
    sed = S.FileSpectrum(sed_filename)
    
    
    # retrieve the filter
   
    bp_ctio=bp_ctio_red
    #bp_ctio=bp_ctio_blue
    #bp_ctio=bp_ctio_nof
        
    atm_filter_name='CTIO atm {}'.format(idx)
    
    # atmosphere passband
    the_bp_atm= S.ArrayBandpass(all_wl_atm[idx]*10.,all_tr_atm[idx], name=atm_filter_name)  # Pysynphot pass band
    # total passband
    bp_ctio_atm = bp_ctio*the_bp_atm # Multply atm tansmission by CCD QE efficiciency
    bp_ctio_atm.binning=10.
    
    # now compute the observed spectrum
    obs_ctio = S.Observation(sed,bp_ctio_atm)
    
    #backup
    all_obs_spectra.append(obs_ctio)
    all_obs_wl.append(obs_ctio.wave)
    all_obs_fluxes.append(obs_ctio.flux)
# Out:
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 0)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 1)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 3)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 4)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 5)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 6)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 7)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 8)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 9)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 10)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 11)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 12)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 13)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 14)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 15)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 16)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 17)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 18)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 19)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((((CTIO QE * CTIO Mirror2) * RG175) * CTIO atm 20)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.

# %%
all_len=[len(all_obs_wl[i]) for i in range(len(all_obs_wl))]

# %%
min_len=min(all_len)

# %%
for i in range(len(all_obs_wl)):
    plt.plot(all_obs_wl[i])

# %%
def MakeSimNpArray(all_simwavelength,all_simspectra,minlen):
    
    all_simspectra=np.array(all_simspectra)
    simwavelength=np.array(all_simwavelength[0][0:minlen])
    
    NBSPEC=all_simspectra.shape[0]
    NBWL=minlen
    
    print NBSPEC,' , ',NBWL
    dataout=np.zeros((NBSPEC+1,NBWL))
    
    dataout[0,:]=simwavelength
    
    for ispec in np.arange(1,NBSPEC+1):
        dataout[ispec,:]=np.copy(all_simspectra[ispec-1][0:minlen])
    return dataout

# %%
spectra_out=MakeSimNpArray(all_obs_wl,all_obs_fluxes,min_len)
# Out:
# 21  ,  4840

# %%
plt.figure(figsize=(20,20))
plt.imshow(spectra_out[:,:],vmin=0,vmax=1e-12)

# %%
def CompareSpectrumProfile(allspectra,object_name):
    """
    CompareSpectrumProfile
    =====================
    
    """
    shortfilename='CompareSimSpec_'+object_name+'.pdf'
    title="Compare simulated spectra for {}".format(object_name)
    figfilename=shortfilename
    pp = PdfPages(figfilename) # create a pdf file
    
    
    f, axarr = plt.subplots(1,1,figsize=(25,12))
    f.suptitle(title,size=40)
    
    NBSPEC=allspectra.shape[0]-1
    wl=allspectra[0]
    
    
    min_z=truncate(min(all_pwv),2)
    max_z=truncate(max(all_pwv),2)
    
    maxim_y_to_plot= []

    texte='pwv : {} - {} mm '.format(min_z,max_z)
    
    for index in np.arange(0,NBSPEC):
                
        axarr.plot(wl/10.,allspectra[index+1],'-',lw=2)
        maxim_y_to_plot.append(allspectra[index+1].max())
    
    axarr.plot(wl/10.,allspectra[0+1],'r-',lw=2)
    
    max_y_to_plot=max(maxim_y_to_plot)
    axarr.set_ylim(0,max_y_to_plot)
    axarr.text(600.,max_y_to_plot*0.9, texte ,verticalalignment='top', horizontalalignment='left',color='blue',fontweight='bold', fontsize=30)
    axarr.grid(True)
    axarr.set_xlim(600,1100)
    
    axarr.get_xaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    axarr.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    axarr.grid(b=True, which='major', color='k', linewidth=2.0)
    axarr.grid(b=True, which='minor', color='grey', linewidth=0.5)
    
    
    
    axarr.set_xlabel("wavelength (nm)",fontsize=30)
    axarr.set_ylabel("relative flux (a.u)",fontsize=30)
    
        
    f.savefig(pp, format='pdf')
    f.show()
    
    pp.close()

# %%
import matplotlib 
matplotlib.rc('xtick', labelsize=30) 
matplotlib.rc('ytick', labelsize=30)

# %%
CompareSpectrumProfile(spectra_out,object_name)

# %% [markdown]
# ## Save output file

# %%
prihdu = fits.PrimaryHDU(data=spectra_out)
thdulist = fits.HDUList(prihdu)
thdulist.writeto(outputfitsfile,overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-163-9fbfdf563d9e> in <module>()
#       1 prihdu = fits.PrimaryHDU(data=spectra_out)
#       2 thdulist = fits.HDUList(prihdu)
# ----> 3 thdulist.writeto(outputfitsfile,overwrite=True)
#
# NameError: name 'outputfitsfile' is not defined

# %%
spectra_out.shape
