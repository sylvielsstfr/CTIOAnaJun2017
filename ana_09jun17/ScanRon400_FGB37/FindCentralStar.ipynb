# %% [markdown]
# # Find the central star of CTIO Data in May 2017
# ==================================================================================================
#
# - author : Jérémy Neveu
# - date   : May 31st 2017
#
#
# The goal of this notebook is to cut a part of the image around the main central star.
# The rest of the image is useless.
# This region around the central star is necessary to perform the rotation of the images without
# any biases due to other stars.

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "theNotebook = " + "'"+thename+"'";
# kernel.execute(command);

# %%
print theNotebook
# Out:
# FindCentralStar

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from astropy.modeling import models
from astropy import units as u
from astropy import nddata
from astropy.io import fits
import re
import os

# %%
import ccdproc
print 'ccdproc version',ccdproc.__version__

from astropy.modeling import models
# Out:
# ccdproc version 1.2.0

# %%
from scipy import stats  
from scipy import ndimage
from datetime import datetime, timedelta
from mpl_toolkits.mplot3d import Axes3D
import scipy.signal

# %%
import bottleneck as bn  # numpy's masked median is slow...really slow (in version 1.8.1 and lower)
print 'bottleneck version',bn.__version__
# Out:
# bottleneck version 1.2.0

# %%
import photutils
from astropy.stats import sigma_clipped_stats
from photutils import daofind
from photutils import CircularAperture
from astropy.visualization import SqrtStretch
from astropy.visualization.mpl_normalize import ImageNormalize
#from photutils.background import Background2D
from photutils import Background2D, SigmaClip, MedianBackground

# %%
# %load_ext Cython

# %%
from IPython.display import Image, display

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (4, 4),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
############################################################################
def ensure_dir(f):
    d = os.path.dirname(f)
    if not os.path.exists(f):
        os.makedirs(f)
#########################################################################

# %% [markdown]
# ### Output directory for images generated in the notebook view (not true fits images)¶

# %%
dir_top_images="images_notebooks/"+theNotebook ### Top directory to save images

# %%
ensure_dir(dir_top_images) # create that directory

# %% [markdown]
# ### Input directory

# %%
# !ls ../OverScanRemove/trim_images
# Out:
# trim_20170609_004.fits trim_20170609_047.fits trim_20170609_088.fits
# trim_20170609_005.fits trim_20170609_048.fits trim_20170609_089.fits
# trim_20170609_006.fits trim_20170609_049.fits trim_20170609_090.fits
# trim_20170609_007.fits trim_20170609_050.fits trim_20170609_091.fits
# trim_20170609_008.fits trim_20170609_051.fits trim_20170609_092.fits
# trim_20170609_009.fits trim_20170609_052.fits trim_20170609_093.fits
# trim_20170609_010.fits trim_20170609_053.fits trim_20170609_094.fits
# trim_20170609_011.fits trim_20170609_054.fits trim_20170609_095.fits
# trim_20170609_012.fits trim_20170609_055.fits trim_20170609_096.fits
# trim_20170609_013.fits trim_20170609_056.fits trim_20170609_097.fits
# trim_20170609_014.fits trim_20170609_057.fits trim_20170609_098.fits
# trim_20170609_015.fits trim_20170609_058.fits trim_20170609_099.fits
# trim_20170609_016.fits trim_20170609_059.fits trim_20170609_100.fits
# trim_20170609_017.fits trim_20170609_060.fits trim_20170609_101.fits
# trim_20170609_018.fits trim_20170609_061.fits trim_20170609_102.fits
# trim_20170609_019.fits trim_20170609_062.fits trim_20170609_103.fits
# trim_20170609_020.fits trim_20170609_063.fits trim_20170609_104.fits
# trim_20170609_021.fits trim_20170609_064.fits trim_20170609_105.fits
# trim_20170609_022.fits trim_20170609_065.fits trim_20170609_106.fits
# trim_20170609_023.fits trim_20170609_066.fits trim_20170609_107.fits
# trim_20170609_024.fits trim_20170609_067.fits trim_20170609_108.fits
# trim_20170609_025.fits trim_20170609_068.fits trim_20170609_109.fits
# trim_20170609_026.fits trim_20170609_069.fits trim_20170609_110.fits
# trim_20170609_027.fits trim_20170609_070.fits trim_20170609_111.fits
# trim_20170609_028.fits trim_20170609_071.fits trim_20170609_112.fits
# trim_20170609_031.fits trim_20170609_072.fits trim_20170609_113.fits
# trim_20170609_032.fits trim_20170609_073.fits trim_20170609_114.fits
# trim_20170609_033.fits trim_20170609_074.fits trim_20170609_115.fits
# trim_20170609_034.fits trim_20170609_075.fits trim_20170609_116.fits
# trim_20170609_035.fits trim_20170609_076.fits trim_20170609_117.fits
# trim_20170609_036.fits trim_20170609_077.fits trim_20170609_118.fits
# trim_20170609_037.fits trim_20170609_078.fits trim_20170609_119.fits
# trim_20170609_038.fits trim_20170609_079.fits trim_20170609_120.fits
# trim_20170609_039.fits trim_20170609_080.fits trim_20170609_121.fits
# trim_20170609_040.fits trim_20170609_081.fits trim_20170609_122.fits
# trim_20170609_041.fits trim_20170609_082.fits trim_20170609_123.fits
# trim_20170609_042.fits trim_20170609_083.fits trim_20170609_124.fits
# trim_20170609_043.fits trim_20170609_084.fits trim_20170609_125.fits
# trim_20170609_044.fits trim_20170609_085.fits trim_20170609_126.fits
# trim_20170609_045.fits trim_20170609_086.fits trim_20170609_127.fits
# trim_20170609_046.fits trim_20170609_087.fits trim_20170609_128.fits

# %%
inputdir="../OverScanRemove/trim_images"
MIN_IMGNUMBER=4
MAX_IMGNUMBER=28
object_name='HD111980'
SelectTagRe='^trim_20170609_([0-9]+).fits$' # regular expression to select the file
SearchTagRe='^trim_20170609_[0-9]+.fits$'
NBIMGPERLROW=4

# %% [markdown]
# ### Output directory fot fits images

# %%
outputdir="./cut_fitsimages"

# %%
ensure_dir(outputdir)

# %% [markdown]
# ## Location of corrected images
# ----------------------------------

# %%
input_filelist=os.listdir(inputdir)

# %%
if '.DS_Store' in input_filelist:
    input_filelist.remove('.DS_Store')
input_filelist=np.array(input_filelist)

# %%
print input_filelist[:5]
# Out:
# ['trim_20170609_004.fits' 'trim_20170609_005.fits' 'trim_20170609_006.fits'
#  'trim_20170609_007.fits' 'trim_20170609_008.fits']

# %%
indexes_files= [] # global list
filelist_fitsimages= []  # global list
dirlist_all = [inputdir]

# %%
def MakeFileList():
    """
    MakeFileList : Make The List of files to open
    =============
    
    - we select the files which are of interest.
    - In particular select the number range
    
    """
    count=0
    
    for dir in dirlist_all: # loop on directories, one per image   (if necessary)    
            dir_leaf= dir # build the name of leaf directory
            listfiles=os.listdir(dir_leaf) 
            for filename in listfiles:
                if re.search(SearchTagRe,filename):  #example of filename filter
                    str_index=re.findall(SelectTagRe,filename)
                    count=count+1
                    index=int(str_index[0])
                    if index >= MIN_IMGNUMBER and index <= MAX_IMGNUMBER: 
                        indexes_files.append(index)         
                        shortfilename=dir_leaf+'/'+filename
                        filelist_fitsimages.append(shortfilename)
                    
    return

# %%
MakeFileList()   # Make the list

# %%
indexes_files=np.array(indexes_files)
filelist_fitsimages=np.array(filelist_fitsimages)

# %%
sorted_indexes=np.argsort(indexes_files) # sort the file indexes

# %%
sorted_numbers=indexes_files[sorted_indexes]

# %%
#sorted_files= [filelist_fitsimages[index] for index in sorted_indexes] # sort files
sorted_files=filelist_fitsimages[sorted_indexes]

# %% [markdown]
# ## Build full filename
# ----------------------------

# %%
sorted_filenames=[]
for file in sorted_files:
    #fullfilename=os.path.join(inputdir,file)
    fullfilename=file
    sorted_filenames.append(fullfilename)

# %%
#sorted_filenames=np.array(sorted_filenames)
sorted_filenames=np.copy(sorted_files)

# %% [markdown]
# ## Acces to data of  images
# ----------------------------------

# %%
all_dates = []
all_airmass = []
all_images = []
all_titles = []
all_header = []
all_img = []
all_filt = []

# %%
# %%cython
#
# import numpy as np
# from astropy.io import fits
#
# def BuildImages(sorted_filenames,sorted_numbers,object_name):
#     """
#     BuildRawImages
#     ===============
#     """
#
#
#     all_dates = []
#     all_airmass = []
#     all_images = []
#     all_titles = []
#     all_header = []
#     all_filt = []
#
#     NBFILES=sorted_filenames.shape[0]
#
#     for idx in range(NBFILES):
#
#         file=sorted_filenames[idx]
#
#         hdu_list=fits.open(file)
#         header=hdu_list[0].header
#         #print header
#         date_obs = header['DATE-OBS']
#         airmass = header['AIRMASS']
#         filters = header['FILTERS']
#
#         num=sorted_numbers[idx]
#         title=object_name+" z= {:3.2f} Nb={}".format(float(airmass),num)
#         image_corr=hdu_list[0].data
#         image=image_corr
#
#         all_dates.append(date_obs)
#         all_airmass.append(float(airmass))
#         all_images.append(image)
#         all_titles.append(title)
#         all_header.append(header)
#         all_filt.append(filters)
#         hdu_list.close()
#
#     return all_dates,all_airmass,all_images,all_titles,all_header,all_filt

# %%
all_dates,all_airmass,all_images,all_titles,all_header,all_filt=BuildImages(sorted_files,sorted_numbers,object_name)

# %%
#all_filt

# %% [markdown]
# ## Show images
# -----------------------

# %%
len(all_images)
# Out:
# 25

# %%
def ShowRawImages():
    """
    ShowRawImages: Show the raw images without background subtraction
    ==============
    """
    #global all_images
    #global all_titles
    #global object_name

    NBIMAGES=len(all_images)
    MAXIMGROW=int(NBIMAGES/NBIMGPERLROW)+1

    f, axarr = plt.subplots(MAXIMGROW,NBIMGPERLROW,figsize=(25,5*MAXIMGROW))
    for index in np.arange(0,NBIMAGES):
        ix=index%NBIMGPERLROW
        iy=index/NBIMGPERLROW
        #im=axarr[iy,ix].imshow(all_images[index],origin='lower',cmap='rainbow',norm=LogNorm(vmin=0.1, vmax=10))
        im=axarr[iy,ix].imshow(all_images[index],origin='lower',cmap='rainbow',vmin=0, vmax=800)
        axarr[iy,ix].set_title(all_titles[index])
        axarr[iy,ix].grid(color='white', ls='solid')
        axarr[iy,ix].text(1000.,1700,all_filt[index],verticalalignment='bottom', horizontalalignment='center',color='yellow', fontweight='bold',fontsize=16)
    title='Raw images of {}'.format(object_name)
    plt.suptitle(title,size=16)    
    figfilename=os.path.join(dir_top_images,'input_images.pdf')
    plt.savefig(figfilename)

# %%
ShowRawImages()

# %% [markdown]
# ### Find the star locations
# ----------------------------

# %%
# %%cython
# import photutils
# from astropy.stats import sigma_clipped_stats
# from photutils import daofind
#
# def ComputeStatImages(all_images):
#     """
#     ComputeStatImages:
#     ==============
#     """
#
#     img_mean=[]
#     img_median=[]
#     img_std=[]
#     img_sources=[]
#     img_=[]
#     index=0
#     for image in all_images:
#         mean, median, std = sigma_clipped_stats(image, sigma=10.0, iters=5)
#         print '----------------------------------------------------------------'
#         print index,' mean, median, std = ',mean, median, std
#         img_mean.append(mean)
#         img_median.append(median)
#         img_std.append(std)
#         sources = daofind(image - median, fwhm=22, threshold=300*std) # (JN) valeurs optimisées pour cette étude
#         print sources
#         img_sources.append(sources)
#         index+=1
#     return img_mean,img_median,img_std,img_sources

# %%
img_mean,img_median,img_std,img_sources=ComputeStatImages(all_images)
# Out:
# ----------------------------------------------------------------
# 0  mean, median, std =  101.353388759 117.0 47.2750078701
# WARNING: AstropyDeprecationWarning: The daofind function is deprecated and may be removed in a future version.
#         Use DAOStarFinder instead. [astropy.utils.decorators]
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 335.615204924 342.807982487 ... 60606.0 22.9300336474 -3.40101173003
# ----------------------------------------------------------------
# 1  mean, median, std =  101.877201236 117.0 47.8642978054
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 671.567301808 342.152456077 ... 60605.0 21.8030794466 -3.34629459321
# ----------------------------------------------------------------
# 2  mean, median, std =  101.854641442 118.0 48.1572984778
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1007.10162421 341.320714458 ... 60604.0 20.7234443858 -3.29115484986
# ----------------------------------------------------------------
# 3  mean, median, std =  103.340499571 119.0 48.5068704898
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1342.76744261 341.099962304 ... 61493.0 21.7601257124 -3.34415350009
# ----------------------------------------------------------------
# 4  mean, median, std =  103.824325211 120.0 48.4665972307
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1679.91245539 340.673909344 ... 61494.0 22.0488775329 -3.35846621312
# ----------------------------------------------------------------
# 5  mean, median, std =  104.089194543 120.0 48.4354734837
#  id   xcentroid     ycentroid   ...   peak      flux          mag
# --- ------------- ------------- ... ------- ------------ --------------
#   1 333.619384891 676.800182746 ... 60602.0 21.333085933 -3.32263420692
# ----------------------------------------------------------------
# 6  mean, median, std =  103.644215392 120.0 48.9960817274
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 686.126620953 676.328018692 ... 60603.0 21.1742617533 -3.31452069366
# ----------------------------------------------------------------
# 7  mean, median, std =  104.687460749 121.0 49.2760904387
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1006.24975075 675.974189758 ... 60601.0 20.3079678924 -3.26916617025
# ----------------------------------------------------------------
# 8  mean, median, std =  104.767915842 121.0 49.5157724663
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1342.17194095 675.887468559 ... 61490.0 20.5009586545 -3.27943542442
# ----------------------------------------------------------------
# 9  mean, median, std =  105.947435861 122.0 49.4821133162
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1677.87099278 675.742471833 ... 61489.0 21.0187328931 -3.30651632798
# ----------------------------------------------------------------
# 10  mean, median, std =  105.305761656 122.0 49.4076623641
#  id  xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------ ------------- ... ------- ------------- --------------
#   1 331.72522364 1011.79683834 ... 60601.0 20.0388009212 -3.25467932681
# ----------------------------------------------------------------
# 11  mean, median, std =  105.562104012 122.0 49.9351732214
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 669.552313219 1011.78900529 ... 60600.0 19.9742810261 -3.25117788961
# ----------------------------------------------------------------
# 12  mean, median, std =  106.932839911 124.0 50.3786516953
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1006.25615059 1010.74001231 ... 60596.0 20.0394564443 -3.25471484358
# ----------------------------------------------------------------
# 13  mean, median, std =  106.465971387 123.0 50.538333108
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1342.08484721 1010.24190579 ... 61487.0 20.8777601137 -3.29920975804
# ----------------------------------------------------------------
# 14  mean, median, std =  106.918658134 124.0 50.3647932611
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1678.61135446 1010.23132544 ... 61486.0 20.9669660099 -3.30383897787
# ----------------------------------------------------------------
# 15  mean, median, std =  106.85451403 124.0 50.3510781224
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 332.841861909 1349.29402089 ... 61696.0 20.5779491875 -3.28350522624
# ----------------------------------------------------------------
# 16  mean, median, std =  107.542403448 125.0 50.8588446694
#  id  xcentroid    ycentroid   ...   peak       flux          mag
# --- ------------ ------------ ... ------- ------------- --------------
#   1 668.20976184 1348.6492616 ... 61697.0 19.3702143927 -3.21783606897
# ----------------------------------------------------------------
# 17  mean, median, std =  108.632838703 126.0 51.2209671088
#  id   xcentroid     ycentroid   ...   peak      flux          mag
# --- ------------- ------------- ... ------- ------------ --------------
#   1 1004.45232876 1348.04142699 ... 61695.0 19.422977737 -3.22078953093
# ----------------------------------------------------------------
# 18  mean, median, std =  109.943041597 127.0 51.7433922
#  id   xcentroid     ycentroid   ...   peak      flux         mag
# --- ------------- ------------- ... ------- ------------ ------------
#   1 1339.64991625 1348.11572545 ... 60195.0 20.570202052 -3.283096394
# ----------------------------------------------------------------
# 19  mean, median, std =  109.466467817 127.0 51.5113885415
#  id   xcentroid    ycentroid   ...   peak       flux          mag
# --- ------------- ------------ ... ------- ------------- --------------
#   1 1677.05289466 1347.8265987 ... 60196.0 20.5468217305 -3.28186163224
# ----------------------------------------------------------------
# 20  mean, median, std =  109.303319546 127.0 51.5251550183
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 330.648330035 1684.31520706 ... 61694.0 20.4768002094 -3.27815523232
# ----------------------------------------------------------------
# 21  mean, median, std =  110.056176961 128.0 52.0608641189
#  id   xcentroid     ycentroid   ...   peak      flux          mag
# --- ------------- ------------- ... ------- ------------ --------------
#   1 668.221161985 1683.69426785 ... 61693.0 19.899243703 -3.24709142697
# ----------------------------------------------------------------
# 22  mean, median, std =  111.835185384 129.0 52.3446892766
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- -------------
#   1 1004.04568767 1683.36728077 ... 61694.0 19.6634857469 -3.2341512693
# ----------------------------------------------------------------
# 23  mean, median, std =  111.334737125 129.0 52.6590111047
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1341.23524272 1683.14030421 ... 60195.0 18.7517725188 -3.18260581466
# ----------------------------------------------------------------
# 24  mean, median, std =  112.787354064 131.0 52.6434393619
#  id   xcentroid     ycentroid   ...   peak       flux          mag
# --- ------------- ------------- ... ------- ------------- --------------
#   1 1675.14406863 1683.36249109 ... 60195.0 19.7586191928 -3.23939147792

# %% [markdown]
# ### Central star positions

# %%
x_star = []
y_star = []
for s in img_sources:
    for ss in s :
        x_star.append(ss["xcentroid"])
        y_star.append(ss["ycentroid"])

# %%
positions_central = np.array([y_star, x_star]).T
print positions_central
# Out:
# [[  342.80798249   335.61520492]
#  [  342.15245608   671.56730181]
#  [  341.32071446  1007.10162421]
#  [  341.0999623   1342.76744261]
#  [  340.67390934  1679.91245539]
#  [  676.80018275   333.61938489]
#  [  676.32801869   686.12662095]
#  [  675.97418976  1006.24975075]
#  [  675.88746856  1342.17194095]
#  [  675.74247183  1677.87099278]
#  [ 1011.79683834   331.72522364]
#  [ 1011.78900529   669.55231322]
#  [ 1010.74001231  1006.25615059]
#  [ 1010.24190579  1342.08484721]
#  [ 1010.23132544  1678.61135446]
#  [ 1349.29402089   332.84186191]
#  [ 1348.6492616    668.20976184]
#  [ 1348.04142699  1004.45232876]
#  [ 1348.11572545  1339.64991625]
#  [ 1347.8265987   1677.05289466]
#  [ 1684.31520706   330.64833004]
#  [ 1683.69426785   668.22116198]
#  [ 1683.36728077  1004.04568767]
#  [ 1683.14030421  1341.23524272]
#  [ 1683.36249109  1675.14406863]]

# %%
# Default position
x0 = x_star[len(img_sources)/2]
y0 = y_star[len(img_sources)/2]

# %%
img_size=all_images[0].shape
plt.figure(figsize=(5,5))
plt.plot(x_star,y_star,'o')
plt.plot(x0,y0,'ro')
plt.xlim(0,img_size[1])
plt.ylim(0,img_size[0])
plt.grid(True)

# %% [markdown]
# ### Cut the image

# %%
DeltaY=200
DeltaX=600

# %%
#%%cython

import numpy as np
import matplotlib.pyplot as plt
from photutils import CircularAperture
import os

def ShowCenterImages(all_images,all_titles,object_name,positions_central,dir_top_images):
    """
    ShowCenterImages: Show the raw images without background subtraction
    ==============
    """
    NBIMAGES=len(all_images)
    MAXIMGROW=int(NBIMAGES/NBIMGPERLROW)+1
    
    #global dir_top_images
    
    croped_images = []
    f, axarr = plt.subplots(MAXIMGROW,NBIMGPERLROW,figsize=(25,3*MAXIMGROW))
    for index in np.arange(0,NBIMAGES):
        ix=index%NBIMGPERLROW
        iy=index/NBIMGPERLROW
        y0=int(positions_central[index][0])
        x0=int(positions_central[index][1])
       
        #image_cut=all_images[index][y0-200:y0+200,x0-200,y0+200]
        theimage=all_images[index]
        #image_cut=theimage[y0-DeltaY:y0+DeltaY,x0-DeltaX:x0+DeltaX]
        image_cut=np.copy(theimage[y0-DeltaY:y0+DeltaY,:])
        croped_images.append(image_cut)
        #aperture=CircularAperture([positions_central[index]], r=100.)
        im=axarr[iy,ix].imshow(image_cut,cmap='rainbow',vmin=0,vmax=1000,origin='lower',interpolation='None')
        axarr[iy,ix].set_title(all_titles[index])
        axarr[iy,ix].grid(color='white', ls='solid')
        #aperture.plot(color='red', lw=5.)
    title='Cut Images of {}'.format(object_name)
    plt.suptitle(title,size=16) 
    
    figfilename=os.path.join(dir_top_images,'cut_images.pdf')
    plt.savefig(figfilename)   
    
    
    return croped_images

# %%
images_cut=ShowCenterImages(all_images,all_titles,object_name,positions_central,dir_top_images)

# %% [markdown]
# #### Example of cut image
# -------------------------

# %%
index=0
data=np.copy(images_cut[index])
w=20
ws=80
#data[:,DeltaX-ws:DeltaX+ws]=0

# %%
yprofile=np.sum(data,axis=1)
xprofile=np.sum(data,axis=0)

# %%
y_center=np.where(yprofile==yprofile.max())[0][0]
print y_center
# Out:
# 199

# %%
plt.figure(figsize=(18,18))
y0=int(positions_central[index][0])
x0=int(positions_central[index][1])
plt.imshow(data,vmin=-10,vmax=800,origin='lower',cmap='rainbow',interpolation='None')
plt.plot([0,data.shape[1]],[y_center-w,y_center-w],'r-',lw=1)
plt.plot([0,data.shape[1]],[y_center+w,y_center+w],'r-',lw=1)
plt.grid(color='white', ls='solid')
plt.show()
figfilename=os.path.join(dir_top_images,'cutimages_sample.pdf')
plt.savefig(figfilename)

# %% [markdown]
# ### prepare outputfilename

# %%
newfullfilenames=[]
for idx,file in np.ndenumerate(sorted_files):
    
    short_infilename=file.split("/")[3]
    print short_infilename
    short_partfilename=re.findall('^trim_(.*)',short_infilename)
    short_outfilename='cutimg_'+short_partfilename[0]
    newfullfilename=os.path.join(outputdir,short_outfilename)
    newfullfilenames.append(newfullfilename)
# Out:
# trim_20170609_004.fits
# trim_20170609_005.fits
# trim_20170609_006.fits
# trim_20170609_007.fits
# trim_20170609_008.fits
# trim_20170609_009.fits
# trim_20170609_010.fits
# trim_20170609_011.fits
# trim_20170609_012.fits
# trim_20170609_013.fits
# trim_20170609_014.fits
# trim_20170609_015.fits
# trim_20170609_016.fits
# trim_20170609_017.fits
# trim_20170609_018.fits
# trim_20170609_019.fits
# trim_20170609_020.fits
# trim_20170609_021.fits
# trim_20170609_022.fits
# trim_20170609_023.fits
# trim_20170609_024.fits
# trim_20170609_025.fits
# trim_20170609_026.fits
# trim_20170609_027.fits
# trim_20170609_028.fits

# %% [markdown]
# ### Save outputfilename

# %%
for idx,file in np.ndenumerate(newfullfilenames):
    prihdu = fits.PrimaryHDU(header=all_header[idx[0]],data=images_cut[idx[0]])
    thdulist = fits.HDUList(prihdu)
    thdulist.writeto(file,overwrite=True)
textfilename=os.path.join(outputdir,'star_centroids.txt')
print textfilename
np.savetxt(textfilename,positions_central,header="y_star x_star",fmt='%d')
# Out:
# ./cut_fitsimages/star_centroids.txt

# %%
# !ls -l cut_fitsimages/*
# Out:
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_004.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_005.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_006.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_007.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_008.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_009.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_010.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_011.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_012.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_013.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_014.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_015.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_016.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_017.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_018.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_019.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_020.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_021.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_022.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_023.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_024.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_025.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_026.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_027.fits
# -rw-r--r--  1 jneveu  staff  6566400 10 jui 06:44 cut_fitsimages/cutimg_20170609_028.fits
# -rw-r--r--  1 jneveu  staff      246 10 jui 06:44 cut_fitsimages/star_centroids.txt
