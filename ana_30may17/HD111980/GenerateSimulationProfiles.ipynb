# %% [markdown]
# # Simulation of observed spectrum
#
# - author : Sylvie Dagoret-Campagne
# - date jun 19th 2017

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "theNotebook = " + "'"+thename+"'";
# kernel.execute(command);

# %%
print(theNotebook)
# Out:
# GenerateSimulationProfiles

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

from astropy.modeling import models
from astropy import units as u
from astropy import nddata
from astropy.io import fits
from astropy.table import Table, Column
import re
import os

# %%
import pandas as pd

# %%
from matplotlib.backends.backend_pdf import PdfPages

# %% [markdown]
# ### Import libradtan tools for simulation

# %%
import sys
sys.path.append('../../spectrumsim/libradtransim')

# %%
from libsimulateTranspCTIOScattAbs import *

# %% [markdown]
# ### import pysynphot tools for CALSPEC SED

# %%
os.environ['PYSYN_CDBS']
# Out:
# '/Users/dagoret-campagnesylvie/MacOsX/External/PySyn_CDBS/grp/hst/cdbs'

# %%
import pysynphot as S
from astropy.io import ascii

# %% [markdown]
# ### CTIO Properties

# %%
path_ctiodata='../../spectrumsim/CTIOThroughput'
qe_filename='qecurve.txt'

# %% [markdown]
# ### esthetic

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (8, 6),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
############################################################################
def ensure_dir(f):
    d = os.path.dirname(f)
    if not os.path.exists(f):
        os.makedirs(f)
#########################################################################

# %%
def truncate(f, n):
    '''Truncates/pads a float f to n decimal places without rounding'''
    s = '{}'.format(f)
    if 'e' in s or 'E' in s:
        return '{0:.{1}f}'.format(f, n)
    i, p, d = s.partition('.')
    return '.'.join([i, (d+'0'*n)[:n]])

# %%
infos='ctio30may2017'

# %%
rootpath_rawimage="../OverScanRemove/trim_images"
MIN_IMGNUMBER=58
MAX_IMGNUMBER=199
object_name='HD111980_May_30th'
SelectTagRe='^trim_20170530_([0-9]+).fits$' # regular expression to select the file
SearchTagRe='^trim_20170530_[0-9]+.fits$'
NBIMGPERLROW=4
calspec_sed='hd111980_stis_003.fits'

# %%
logfile='logbk_'+object_name+'_'+infos+'.fits'
pandaslogfile='logbk_'+object_name+'_'+infos+'.csv'

# %%
outputfitsfile='AllSimSpectra_'+object_name+'.fits'

# %%
dir_top_images="images_notebooks/"+theNotebook ### Top directory to save images

# %%
ensure_dir(dir_top_images)

# %% [markdown]
# ## Get list of airmass

# %%
df=pd.read_csv(pandaslogfile)

# %%
df.head()
# Out:
#    Unnamed: 0  number  airmass                     date  \
# 0           0      58    1.051  2017-05-31T00:02:18.596
# 1           1      59    1.049  2017-05-31T00:04:09.003
# 2           2      60    1.047  2017-05-31T00:06:14.000
# 3           3      61    1.045  2017-05-31T00:08:06.454
# 4           4      62    1.044  2017-05-31T00:09:58.852
#
#                          filename  exposure     zenith  temperature  pressure  \
# 0  ../OverScanRemove/trim_images/      60.0  17.969000          9.3     783.0
# 1  ../OverScanRemove/trim_images/      10.0  17.608000          9.2     783.0
# 2  ../OverScanRemove/trim_images/      60.0  17.254999          9.1     783.0
# 3  ../OverScanRemove/trim_images/      60.0  16.941999          9.2     783.0
# 4  ../OverScanRemove/trim_images/      60.0  16.634001          9.1     783.0
#
#    humidity  windspeed  seeing filter1  filter2
# 0      26.0        5.5   0.940     dia  Thor300
# 1      26.0        4.6   1.006     dia  Thor300
# 2      26.0        5.7   1.018     dia   Ron400
# 3      26.0        5.5   0.939     dia  Thor300
# 4      26.0        5.8   0.846     dia  HoloPhP

# %%
airmasses=df["airmass"]
date=df['date']
expo=df['exposure']
datafile=df['filename']
temperature=df['temperature']
pressure=df['pressure']
humidity=df['humidity']
seeing=df['seeing']
disperser=df['filter2']

# %% [markdown]
# ## Get quantum efficiency

# %%
qe_fullfilename=os.path.join(path_ctiodata,qe_filename)

# %%
data_qe = np.loadtxt(qe_fullfilename)
wl_qe=data_qe[:,0]
tr_qe=data_qe[:,1]/100.

# %%
bp_ctio = S.ArrayBandpass(wl_qe*10.,tr_qe, name='CTIO QE')

# %% [markdown]
# ## Get SED from CALSPEC
#
# - using Pysynphot

# %%
CTIO_COLL_SURF=0.9*(u.m)**2/(u.cm)**2  # LSST collectif surface
WLMIN=3000.
WLMAX=11000.

# %%
S.refs.setref(area=CTIO_COLL_SURF.decompose(), waveset=None)
S.refs.set_default_waveset(minwave=WLMIN, maxwave=WLMAX, delta=10, log=False)

# %%
filename = os.path.join(os.environ['PYSYN_CDBS'], 'calspec',calspec_sed)
sed = S.FileSpectrum(filename)

# %%
with fits.open(filename) as pf:
    print(pf[1].header)
# Out:
# XTENSION= 'BINTABLE'           /Written by IDL:  Wed Dec 24 09:03:03 2014       BITPIX  =                    8 /                                                NAXIS   =                    2 /Binary table                                    NAXIS1  =                   30 /Number of bytes per row                         NAXIS2  =                 3739 /Number of rows                                  PCOUNT  =                    0 /Random parameter count                          GCOUNT  =                    1 /Group count                                     TFIELDS =                    7 /Number of columns                               EXTNAME = 'SCI     '           /                                                EXTVER  =                    1 /                                                INHERIT =                    T /                                                TFORM1  = '1D      '           /Real*8 (double precision)                       TTYPE1  = 'WAVELENGTH'         /Label for column 1                              TUNIT1  = 'ANGSTROMS'          /Units of column 1                               TDISP1  = 'G10.4   '           /Display format for column 1                     TFORM2  = '1E      '           /Real*4 (floating point)                         TTYPE2  = 'FLUX    '           /Absolutely calibrated net spectrum              TUNIT2  = 'FLAM    '           /Units of column 2                               TDISP2  = 'E12.4   '           /Display format for column 2                     TFORM3  = '1E      '           /Real*4 (floating point)                         TTYPE3  = 'STATERROR'          /Statistical flux error                          TUNIT3  = 'FLAM    '           /Units of column 3                               TDISP3  = 'E12.4   '           /Display format for column 3                     TFORM4  = '1E      '           /Real*4 (floating point)                         TTYPE4  = 'SYSERROR'           /Systematic flux error=0.01*FLAM                 TUNIT4  = 'FLAM    '           /Units of column 4                               TDISP4  = 'E12.4   '           /Display format for column 4                     TFORM5  = '1E      '           /Real*4 (floating point)                         TTYPE5  = 'FWHM    '           /FWHM spectral resolution                        TUNIT5  = 'ANGSTROMS'          /Units of column 5                               TDISP5  = 'G6.2    '           /Display format for column 5                     TFORM6  = '1I      '           /Integer*2 (short integer)                       TTYPE6  = 'DATAQUAL'           /Data quality: 1=good, 0=bad                     TUNIT6  = 'NONE    '           /Units of column 6                               TDISP6  = 'I2      '           /Display format for column 6                     TFORM7  = '1E      '           /Real*4 (floating point)                         TTYPE7  = 'TOTEXP  '           /Total exposure time                             TUNIT7  = 'SEC     '           /Units of column 7                               TDISP7  = 'G10.2   '           /Display format for column 7                     END

# %% [markdown]
# # Simulate atmosphere

# %%
all_wl_atm= []
all_tr_atm= []
all_bp_atm = []
PWV=4.
OZ=300.

# %%
for index,am in np.ndenumerate(airmasses):
    idx=index[0]
    path,file=ProcessSimulation(am,PWV,OZ)   
    fullfilename=os.path.join(path,file)
    atm_data=np.loadtxt(fullfilename)
    wl_atm=atm_data[:,0]
    tr_atm=atm_data[:,1]
    all_wl_atm.append(wl_atm)
    all_tr_atm.append(tr_atm)
    atm_filter_name='CTIO atm {}'.format(idx)
    bp_atm = S.ArrayBandpass(wl_atm*10.,tr_atm, name=atm_filter_name)  # Pysynphot pass band
    all_bp_atm.append(bp_atm)
# Out:
# --------------------------------------------
#  2) airmass =  1.05099999905
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.0490000248
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.04700005054
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.04499995708
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.04400002956
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.04200005531
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03999996185
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03699994087
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03600001335
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03499996662
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03299999237
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03199994564
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02999997139
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02900004387
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02799999714
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02699995041
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02600002289
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02499997616
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02400004864
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02400004864
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02300000191
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02199995518
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02199995518
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02100002766
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02100002766
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02100002766
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02100002766
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02100002766
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02100002766
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02100002766
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02100002766
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02199995518
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02199995518
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02199995518
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02300000191
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02300000191
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02400004864
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02499997616
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02600002289
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02699995041
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02799999714
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.02900004387
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03100001812
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03199994564
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03299999237
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.0340000391
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03600001335
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03900003433
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.03999996185
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.04200005531
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.04299998283
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.04600000381
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.04799997807
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.04999995232
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.05200004578
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.05400002003
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.05700004101
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.06099998951
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.06299996376
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.06500005722
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.06799995899
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.0720000267
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.0759999752
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.07799994946
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.08099997044
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.08399999142
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.08899998665
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.09300005436
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.09599995613
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z10_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z10_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.10000002384
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.10300004482
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.10800004005
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.11399996281
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.11699998379
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.1210000515
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.125
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z11_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z11_wv40_oz30.OUT')
# ...
# --------------------------------------------
#  2) airmass =  1.49000000954
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z14_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z14_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z14_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z14_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.50100004673
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.51300001144
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.52600002289
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.54499995708
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.56500005722
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.57899999619
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.59200000763
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z15_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z15_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.60699999332
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z16_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z16_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z16_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z16_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.6289999485
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z16_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z16_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z16_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z16_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.65199995041
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z16_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z16_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z16_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z16_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.66700005531
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z16_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z16_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z16_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z16_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.68299996853
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z16_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z16_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z16_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z16_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.70000004768
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z17_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z17_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z17_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z17_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.72500002384
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z17_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z17_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z17_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z17_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.75199997425
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z17_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z17_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z17_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z17_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.76999998093
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z17_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z17_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z17_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z17_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.78900003433
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z17_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z17_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z17_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z17_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.80700004101
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z18_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z18_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z18_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z18_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.8370000124
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z18_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z18_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z18_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z18_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.86899995804
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z18_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z18_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z18_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z18_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.88999998569
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z18_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z18_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z18_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z18_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.91100001335
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z19_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z19_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z19_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z19_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.93400001526
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z19_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z19_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z19_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z19_wv40_oz30.OUT')
# --------------------------------------------
#  2) airmass =  1.96899998188
#  2) pwv =  4.0
#  2) oz =  300.0
# --------------------------------------------
# ('Running uvspec with input file: ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z19_wv40_oz30.INP')
# ('Output to file                : ', 'simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z19_wv40_oz30.OUT')
# ('uvspec cmd: ', '/Users/dagoret-campagnesylvie/MacOsX/LSST/softs/libRadtran-2.0.1/bin/uvspec  < simulations/RT/2.0.1/CT/pp/us/sa/rt/in/RT_CT_pp_us_sa_rt_z19_wv40_oz30.INP > simulations/RT/2.0.1/CT/pp/us/sa/rt/out/RT_CT_pp_us_sa_rt_z19_wv40_oz30.OUT')

# %% [markdown]
# ## Observed spectra
#
# - calculate the observed spectra and save it in list

# %%
all_obs_spectra = []
all_obs_wl= []
all_obs_fluxes = []

for index,am in np.ndenumerate(airmasses):
    idx=index[0]
    atm_filter_name='CTIO atm {}'.format(idx)
    the_bp_atm=bp_atm = S.ArrayBandpass(all_wl_atm[idx]*10.,all_tr_atm[idx], name=atm_filter_name)  # Pysynphot pass band
    bp_ctio_atm = bp_ctio*the_bp_atm # Multply atm tansmission by CCD QE efficiciency
    bp_ctio_atm.binning=10.
    obs_ctio = S.Observation(sed,bp_ctio_atm)
    all_obs_spectra.append(obs_ctio)
    all_obs_wl.append(obs_ctio.wave)
    all_obs_fluxes.append(obs_ctio.flux)
# Out:
# ((CTIO QE * CTIO atm 0)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 1)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 2)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 3)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 4)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 5)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 6)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 7)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 8)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 9)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 10)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 11)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 12)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 13)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 14)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 15)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 16)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 17)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 18)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 19)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 20)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 21)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 22)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 23)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 24)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 25)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 26)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 27)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 28)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 29)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 30)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 31)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 32)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 33)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 34)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 35)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 36)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 37)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 38)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 39)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 40)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 41)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 42)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 43)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 44)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 45)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 46)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 47)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 48)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 49)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 50)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 51)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 52)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 53)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 54)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 55)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 56)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 57)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 58)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 59)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 60)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 61)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 62)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 63)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 64)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 65)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 66)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 67)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 68)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 69)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 70)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 71)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 72)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 73)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 74)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 75)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 76)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 77)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 78)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 79)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 80)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 81)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 82)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 83)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 84)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 85)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 86)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 87)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 88)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 89)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 90)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 91)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 92)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 93)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 94)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 95)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 96)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 97)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 98)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 99)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 100)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 101)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 102)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 103)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 104)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 105)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 106)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 107)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 108)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 109)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 110)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 111)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 112)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 113)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 114)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 115)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 116)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 117)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 118)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 119)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 120)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 121)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 122)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 123)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 124)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 125)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 126)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 127)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 128)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 129)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 130)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 131)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 132)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 133)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 134)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 135)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 136)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 137)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 138)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 139)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 140)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ((CTIO QE * CTIO atm 141)) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.

# %%
plt.plot(all_obs_wl[0], all_obs_fluxes[0])
plt.xlim(0,10000)
# Out:
# (0, 10000)

# %%
def MakeSimNpArray(all_simwavelength,all_simspectra):
    
    all_simspectra=np.array(all_simspectra)
    simwavelength=np.array(all_simwavelength[0])
    
    NBSPEC=all_simspectra.shape[0]
    NBWL=simwavelength.shape[0]
    
    print NBSPEC,' , ',NBWL
    dataout=np.zeros((NBSPEC+1,NBWL))
    
    dataout[0,:]=simwavelength
    
    for ispec in np.arange(1,NBSPEC+1):
        dataout[ispec,:]=all_simspectra[ispec-1]
    return dataout

# %%
spectra_out=MakeSimNpArray(all_obs_wl,all_obs_fluxes)
# Out:
# 142  ,  4814

# %%
plt.figure(figsize=(20,20))
plt.imshow(spectra_out[:,:],vmin=0,vmax=1e-12)

# %%
def CompareSpectrumProfile(allspectra,object_name,dir_top_img):
    """
    CompareSpectrumProfile
    =====================
    
    """
    shortfilename='CompareSimSpec_'+object_name+'.pdf'
    title="Compare simulated spectra of {}".format(object_name)
    figfilename=os.path.join(dir_top_img,shortfilename)
    pp = PdfPages(figfilename) # create a pdf file
    
    
    f, axarr = plt.subplots(1,1,figsize=(25,15))
    f.suptitle(title,size=20)
    
    NBSPEC=allspectra.shape[0]-1
    wl=allspectra[0]
    
    
    min_z=truncate(min(airmasses),2)
    max_z=truncate(max(airmasses),2)
    
    maxim_y_to_plot= []

    texte='airmass : {} - {} '.format(min_z,max_z)
    
    for index in np.arange(0,NBSPEC):
                
       
        axarr.plot(wl,allspectra[index+1],'-')
        maxim_y_to_plot.append(allspectra[index+1].max())
    
    max_y_to_plot=max(maxim_y_to_plot)
    axarr.set_ylim(0,max_y_to_plot)
    axarr.text(0.,max_y_to_plot*0.9, texte ,verticalalignment='top', horizontalalignment='left',color='blue',fontweight='bold', fontsize=20)
    axarr.grid(True)
    axarr.set_xlim(0,12000)
    
    axarr.get_xaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    axarr.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    axarr.grid(b=True, which='major', color='k', linewidth=2.0)
    axarr.grid(b=True, which='minor', color='grey', linewidth=0.5)
    
    
    
    axarr.set_xlabel("wavelength (A)")
    
        
    f.savefig(pp, format='pdf')
    f.show()
    
    pp.close()

# %%
CompareSpectrumProfile(spectra_out,object_name,dir_top_images)

# %% [markdown]
# ## Save output file

# %%
prihdu = fits.PrimaryHDU(data=spectra_out)
thdulist = fits.HDUList(prihdu)
thdulist.writeto(outputfitsfile,overwrite=True)

# %%
spectra_out.shape
# Out:
# (143, 4814)

# %%
plt.figure(figsize=(20,20))
plt.imshow(simspectra_data[:,:],vmin=0,vmax=8e-9)
